# %%
import tensorflow as tf

# %%
# Callback class to interrupt the training if we have reached an accurcy of 95% to not overfit
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs={}):
    if(logs.get('accuracy')>0.95):
      print("\nReached an accuracy of 95% so training is cancelled")
      self.model.stop_training = True

# %%
callback = myCallback()
mnist = tf.keras.datasets.fashion_mnist
(training_images, training_labels), (test_images, test_labels) = mnist.load_data()

# normalize the data
training_images = training_images / 255.0
test_images = test_images / 255.0

# %%
# Build the model
model = tf.keras.models.Sequential([
                                    tf.keras.layers.Flatten(),
                                    tf.keras.layers.Dense(128, activation=tf.nn.relu),
                                    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
                                    ])

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
    )

# %%
# Fit the model
model.fit(training_images, training_labels, epochs=50, callbacks=[callback])
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4972 - accuracy: 0.8253
# Epoch 2/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.3728 - accuracy: 0.8662
# Epoch 3/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3345 - accuracy: 0.8775
# Epoch 4/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.3114 - accuracy: 0.8852
# Epoch 5/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2921 - accuracy: 0.8924
# Epoch 6/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2800 - accuracy: 0.8977
# Epoch 7/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2679 - accuracy: 0.8998
# Epoch 8/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2572 - accuracy: 0.9042
# Epoch 9/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2462 - accuracy: 0.9083
# Epoch 10/50
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.2372 - accuracy: 0.9103
# Epoch 11/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2319 - accuracy: 0.9135
# Epoch 12/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2244 - accuracy: 0.9169
# Epoch 13/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2161 - accuracy: 0.9183
# Epoch 14/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2109 - accuracy: 0.9202
# Epoch 15/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.2051 - accuracy: 0.9227
# Epoch 16/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1991 - accuracy: 0.9252
# Epoch 17/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1934 - accuracy: 0.9270
# Epoch 18/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1860 - accuracy: 0.9302
# Epoch 19/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1822 - accuracy: 0.9316
# Epoch 20/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1804 - accuracy: 0.9320
# Epoch 21/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1740 - accuracy: 0.9349
# Epoch 22/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1709 - accuracy: 0.9355
# Epoch 23/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1687 - accuracy: 0.9367
# Epoch 24/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1627 - accuracy: 0.9390
# Epoch 25/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1612 - accuracy: 0.9391
# Epoch 26/50
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.1560 - accuracy: 0.9407
# Epoch 27/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1520 - accuracy: 0.9431
# Epoch 28/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1503 - accuracy: 0.9439
# Epoch 29/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1464 - accuracy: 0.9448
# Epoch 30/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1421 - accuracy: 0.9474
# Epoch 31/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1399 - accuracy: 0.9478
# Epoch 32/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1361 - accuracy: 0.9495
# Epoch 33/50
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1352 - accuracy: 0.9494
# Epoch 34/50
# 1857/1875 [============================>.] - ETA: 0s - loss: 0.1331 - accuracy: 0.9505
# Reached an accuracy of 95% so training is cancelled
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.1332 - accuracy: 0.9505

# %%
# Evaluate on the test set
model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3957 - accuracy: 0.8886
# [0.39570948481559753, 0.8885999917984009]
